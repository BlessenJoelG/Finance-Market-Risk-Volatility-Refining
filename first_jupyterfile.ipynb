# %%
print("blessen is the best")
# Out:
# blessen is the best

# %%
print("he will clean the data")
# Out:
# he will clean the data

# %%
print("he will through the cleaned data at the face of abhishek")
# Out:
# he will through the cleaned data at the face of abhishek
